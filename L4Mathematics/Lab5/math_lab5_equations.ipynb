# %% [markdown]
# # import

# %%
import math
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # briefings

# %%
def Briefings():
    def func1(x):
        return 1/x
    # vectorize the function (so that it can take a numpy array as input)
    np.vectorize(func1)
    # create an array of x values from 0.1 to 1000 in steps of 0.1
    x = np.arange(0.1,1000,0.1)
    y = func1(x)
    print(y)

    # plot the function
    x = np.linspace(-100,100,1000)
    y = 1/x
    plt.plot(x,y, 'g:')
    plt.xlabel('x'); plt.ylabel('y')
Briefings()
# Out:
# [1.00000000e+01 5.00000000e+00 3.33333333e+00 ... 1.00030009e-03
#  1.00020004e-03 1.00010001e-03]

# %% [markdown]
# # exercise tasks 1

# %%
def exercises():
    def exercise_a():
        def func1(x):
            return np.sqrt(x)  # Use numpy sqrt
        func1 = np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(y)
        x = np.linspace(-100, 100, 1000)
        y = np.sqrt(x)
        plt.plot(x, y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    #exercise_a()
    
    def exercise_b():
        def func1(x):
            return math.sqrt(-1/x)  
        func1 = np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(y)
        x = np.linspace(-5, 5, 1000)
        y = math.sqrt(-1/x) 
        plt.plot(x, y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    #exercise_b()

    def exercise_c():
        def func1(x):
            return 2/(x**2)
        func1 = np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(y)
        x = np.linspace(-5, 5, 1000)
        y = 2/(x**2)
        plt.plot(x, y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    exercise_c()

    def exercise_d():
        def func1(x):
            return 1/x**3
        func1 = np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(-y)
        x = np.linspace(-5, 5, 1000)
        y = 2/(x**3)
        plt.plot(x, -y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    #exercise_d()

    def exercise_e():
        def func1(x):
            return np.log(((4*x)-1/x+3)/2)
        func1 = np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(-y)
        x = np.linspace(-5, 5, 1000)
        y = np.log(((4*x)-1/x+3)/2)
        plt.plot(x, -y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    #exercise_e()
        
exercises()
# Out:
# [2.00000000e+02 5.00000000e+01 2.22222222e+01 ... 2.00120054e-06
#  2.00080024e-06 2.00040006e-06]
# [        nan         nan  0.83624802 ... -7.60135211 -7.60145206
#  -7.601552  ]
# C:\Users\riley\AppData\Local\Temp\ipykernel_27600\2837054132.py:56: RuntimeWarning: invalid value encountered in log
#   return np.log(((4*x)-1/x+3)/2)
# C:\Users\riley\AppData\Local\Temp\ipykernel_27600\2837054132.py:62: RuntimeWarning: invalid value encountered in log
#   y = np.log(((4*x)-1/x+3)/2)
