# %% [markdown]
# # import

# %%
import math
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import sympy as sp

# %% [markdown]
# # briefings

# %%
def Briefings():
    def func1(x):
        return 1/x
    # vectorize the function (so that it can take a numpy array as input)
    np.vectorize(func1)
    # create an array of x values from 0.1 to 1000 in steps of 0.1
    x = np.arange(0.1,1000,0.1)
    y = func1(x)
    print(y)

    # plot the function
    x = np.linspace(-100,100,1000)
    y = 1/x
    plt.plot(x,y, 'g:')
    plt.xlabel('x'); plt.ylabel('y')
Briefings()
# Out:
# [1.00000000e+01 5.00000000e+00 3.33333333e+00 ... 1.00030009e-03
#  1.00020004e-03 1.00010001e-03]

# %% [markdown]
# # exercise tasks 1

# %%
def exercises():
    def solving_explicit():
        '''
        x, y = sp.symbols('x y')
        exercise_a_equation = (-1+((y**2)/x))
        print(sp.solve(exercise_a_equation, y))

        exercise_b_equation = (1-x*(y**2))
        print(sp.solve(exercise_b_equation, y))

        exercise_c_equation = (2-y*(x**2))
        print(sp.solve(exercise_c_equation, y))

        exercise_d_equation = 3-y*(x**3)
        print(sp.solve(exercise_d_equation, y))

        exercise_e_equation = (((4*x)-1)/(x+3))-sp.exp(2*y)
        print(sp.solve(exercise_e_equation, y))
        '''
        # solves the domain of the function exercise_e_equation
        x = sp.symbols('x')
        domain_exercise_e = (4*x - 1)/(x + 3)
        e = sp.solve(domain_exercise_e, x)
        x_vals = np.arange(-4.1, 0.1, 0.1)
        e_vals = np.log((4*x_vals - 1)/(x_vals + 3)/2)
        print(e_vals)
        print(x_vals)

        plt.plot(x_vals, e_vals, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
        
        


    solving_explicit()

    def exercise_a():
        def func1(x):
            return np.sqrt(x)  # Use numpy sqrt
        np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(y)
        x = np.linspace(-5, 5, 1000)
        y = np.sqrt(x)
        plt.plot(x, y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    #exercise_a()
    
    def exercise_b():
        def func1(x):
            return math.sqrt(-1/x)  
        func1 = np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(y)
        x = np.linspace(-5, 5, 1000)
        y = math.sqrt(-1/x) 
        plt.plot(x, y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    #exercise_b()

    def exercise_c():
        def func1(x):
            return 2/(x**2)
        func1 = np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(y)
        x = np.linspace(-5, 5, 1000)
        y = 2/(x**2)
        plt.plot(x, y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    #exercise_c()

    def exercise_d():
        def func1(x):
            return 1/x**3
        func1 = np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(-y)
        x = np.linspace(-5, 5, 1000)
        y = 2/(x**3)
        plt.plot(x, -y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    #exercise_d()

    def exercise_e():
        def func1(x):
            return np.log(((4*x)-1/x+3)/2)
        func1 = np.vectorize(func1)
        x = np.arange(0.1, 1000, 0.1)
        y = func1(x)
        print(-y)
        x = np.linspace(0.1, 1000, 1000) 
        y = np.log(((4*x)-1/x+3)/2)
        plt.plot(x, -y, 'g:')
        plt.xlabel('x'); plt.ylabel('y')
    #exercise_e()
exercises()
# Out:
# [2.06801285 2.14006616 2.22161603 2.31500761 2.4235377  2.55204595
#  2.7080502  2.90416508 3.16406759 3.54095932 4.20469262        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
# [-4.10000000e+00 -4.00000000e+00 -3.90000000e+00 -3.80000000e+00
#  -3.70000000e+00 -3.60000000e+00 -3.50000000e+00 -3.40000000e+00
#  -3.30000000e+00 -3.20000000e+00 -3.10000000e+00 -3.00000000e+00
#  -2.90000000e+00 -2.80000000e+00 -2.70000000e+00 -2.60000000e+00
#  -2.50000000e+00 -2.40000000e+00 -2.30000000e+00 -2.20000000e+00
#  -2.10000000e+00 -2.00000000e+00 -1.90000000e+00 -1.80000000e+00
#  -1.70000000e+00 -1.60000000e+00 -1.50000000e+00 -1.40000000e+00
# ...
